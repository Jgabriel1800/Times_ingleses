# %% [markdown]
# <a href="https://colab.research.google.com/github/Jgabriel1800/Times_ingleses/blob/main/premierleague.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly.express as px

# %%
dados_inicio=pd.read_csv('/content/English League 1.csv')
dados_inicio
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
#        AwayGoals Result
# 0            2.0      A
# ...

# %%
dados_inicio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16408 entries, 0 to 16407
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   League     16408 non-null  object
#  1   Date       16408 non-null  object
#  2   HomeTeam   16408 non-null  object
#  3   AwayTeam   16408 non-null  object
#  4   HomeGoals  16408 non-null  float64
#  5   AwayGoals  16408 non-null  float64
#  6   Result     16408 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 897.4+ KB

# %%
dados_inicio[['HomeTeam','AwayTeam','HomeGoals','AwayGoals','Result']]
# Out:
#              HomeTeam     AwayTeam  HomeGoals  AwayGoals Result
# 0              Barnet         Hull        1.0        2.0      A
# 1            Bradford     Brighton        2.0        0.0      H
# 2           Brentford       Exeter        2.0        1.0      H
# 3         Bristol Rvs  Bournemouth        0.0        1.0      A
# 4             Burnley    Port Vale        2.0        1.0      H
# ...               ...          ...        ...        ...    ...
# 16403         Lincoln   Shrewsbury        1.0        0.0      H
# 16404          Oxford   Accrington        1.0        2.0      A
# 16405       Port Vale     Plymouth        1.0        3.0      A
# 16406      Portsmouth      Wycombe        2.0        2.0      D
# 16407  Sheffield Weds        Derby        1.0        0.0      H
#
# [16408 rows x 5 columns]

# %%
media_gols_casa=dados_inicio['HomeGoals'].mean()

# %% [markdown]
# **times com gols abaixo da media **

# %%
dados_inicio.loc[dados_inicio['HomeGoals'] < media_gols_casa, 'HomeTeam']
# Out:
# 0                Barnet
# 3           Bristol Rvs
# 7            Hartlepool
# 8          Huddersfield
# 12            Blackpool
#               ...
# 16398            Burton
# 16403           Lincoln
# 16404            Oxford
# 16405         Port Vale
# 16407    Sheffield Weds
# Name: HomeTeam, Length: 9361, dtype: object

# %%
jogos_casa = dados_inicio.groupby('HomeTeam')['HomeTeam'].transform('count')

# %%
jogos_fora = dados_inicio.groupby('AwayTeam')['AwayTeam'].transform('count')

# %%
times = pd.concat([dados_inicio['HomeTeam'], dados_inicio['AwayTeam']]).unique()
times=pd.DataFrame(times,columns=['times'])

# %% [markdown]
# **Criando colunas**

# %% [markdown]
# Criando coluna de times

# %%
dados_inicio['Times']=times
dados_inicio['Times'].sort_values()
dados_inicio['Times'] = dados_inicio['Times'].sort_values().values
dados_inicio
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
#        AwayGoals Result          Times
# ...

# %% [markdown]
# Criando coluna de gols dos times

# %%
gols_time=dados_inicio.groupby('HomeTeam')['HomeGoals'].sum() +dados_inicio.groupby('AwayTeam')['AwayGoals'].sum()
dados_inicio['Gols time'] = dados_inicio['Times'].map(gols_time).sort_values().fillna(0)
dados_inicio
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
#        AwayGoals Result          Times  Gols time
# ...

# %% [markdown]
# Criando coluna gols dentro e fora de casa

# %%
gols_time_casa=dados_inicio.groupby('HomeTeam')['HomeGoals'].sum()
dados_inicio['Gols casa']=dados_inicio['Times'].map(gols_time_casa).sort_values().fillna(0)
dados_inicio
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
# ...

# %%
gols_fora=dados_inicio.groupby('AwayTeam')['AwayGoals'].sum()
dados_inicio['Gols fora']=dados_inicio['Times'].map(gols_fora).sort_values().fillna(0)
dados_inicio
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
# ...

# %%
todos_jogos=dados_inicio.groupby('HomeTeam')['HomeTeam'].count() + dados_inicio.groupby('AwayTeam')['AwayTeam'].count()
dados_inicio['Total jogos']=dados_inicio['Times'].map(todos_jogos).sort_values().fillna(0)
dados_inicio
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
# ...

# %% [markdown]
# Criando gráfico do número de gols de cada time

# %%
px.bar(data_frame=dados_inicio,x='Times',y='Gols time',title='Total de gols')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
