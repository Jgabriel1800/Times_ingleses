# %% [markdown]
# <a href="https://colab.research.google.com/github/Jgabriel1800/Times_ingleses/blob/main/premierleague.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly.express as px
import matplotlib.pyplot as plt

# %%
dados_inicio=pd.read_csv('/content/English Premier League.csv')
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result
# 0            0.0        3.0      A
# 1            4.0        1.0      H
# ...

# %%
dados_inicio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11564 entries, 0 to 11563
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   League     11564 non-null  object
#  1   Date       11564 non-null  object
#  2   HomeTeam   11564 non-null  object
#  3   AwayTeam   11564 non-null  object
#  4   HomeGoals  11564 non-null  float64
#  5   AwayGoals  11564 non-null  float64
#  6   Result     11564 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 632.5+ KB

# %%
dados_inicio[['HomeTeam','AwayTeam','HomeGoals','AwayGoals','Result']]
# Out:
#           HomeTeam        AwayTeam  HomeGoals  AwayGoals Result
# 0          Arsenal        Coventry        0.0        3.0      A
# 1      Aston Villa             QPR        4.0        1.0      H
# 2          Chelsea       Blackburn        1.0        2.0      A
# 3        Liverpool  Sheffield Weds        2.0        0.0      H
# 4         Man City           Leeds        1.0        1.0      D
# ...            ...             ...        ...        ...    ...
# 11559      Everton     Bournemouth        1.0        0.0      H
# 11560        Leeds       Tottenham        1.0        4.0      A
# 11561    Leicester        West Ham        2.0        1.0      H
# 11562   Man United          Fulham        2.0        1.0      H
# 11563  Southampton       Liverpool        4.0        4.0      D
#
# [11564 rows x 5 columns]

# %%
media_gols_casa=dados_inicio['HomeGoals'].mean()

# %% [markdown]
# **times com gols abaixo da media **

# %%
dados_inicio.loc[dados_inicio['HomeGoals'] < media_gols_casa, 'HomeTeam']
# Out:
# 0               Arsenal
# 2               Chelsea
# 4              Man City
# 5             Newcastle
# 6                Oldham
#               ...
# 11556         Brentford
# 11557           Chelsea
# 11558    Crystal Palace
# 11559           Everton
# 11560             Leeds
# Name: HomeTeam, Length: 6459, dtype: object

# %%
jogos_casa = dados_inicio.groupby('HomeTeam')['HomeTeam'].transform('count')

# %%
jogos_fora = dados_inicio.groupby('AwayTeam')['AwayTeam'].transform('count')

# %%
times = pd.concat([dados_inicio['HomeTeam'], dados_inicio['AwayTeam']]).unique()
times=pd.DataFrame(times,columns=['times'])

# %% [markdown]
# **Criando colunas**

# %% [markdown]
# Criando coluna de times

# %%
dados_inicio['Times']=times
dados_inicio['Times'].sort_values()
dados_inicio['Times'] = dados_inicio['Times'].sort_values().values
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result        Times
# 0            0.0        3.0      A      Arsenal
# ...

# %% [markdown]
# Criando coluna de gols dos times

# %%
gols_time=dados_inicio.groupby('HomeTeam')['HomeGoals'].sum() +dados_inicio.groupby('AwayTeam')['AwayGoals'].sum()
dados_inicio['Gols time'] = dados_inicio['Times'].map(gols_time).sort_values().fillna(0)
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result        Times  Gols time
# ...

# %% [markdown]
# Criando coluna gols dentro e fora de casa

# %%
gols_time_casa=dados_inicio.groupby('HomeTeam')['HomeGoals'].sum()
dados_inicio['Gols casa']=dados_inicio['Times'].map(gols_time_casa).sort_values().fillna(0)
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result        Times  Gols time  Gols casa
# ...

# %%
gols_fora=dados_inicio.groupby('AwayTeam')['AwayGoals'].sum()
dados_inicio['Gols fora']=dados_inicio['Times'].map(gols_fora).sort_values().fillna(0)
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result        Times  Gols time  Gols casa  \
# ...

# %%
todos_jogos=dados_inicio.groupby('HomeTeam')['HomeTeam'].count() + dados_inicio.groupby('AwayTeam')['AwayTeam'].count()
dados_inicio['Total jogos']=dados_inicio['Times'].map(todos_jogos).sort_values().fillna(0)
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result        Times  Gols time  Gols casa  \
# ...

# %%
todos_jogos_fora=dados_inicio.groupby('HomeTeam')['HomeTeam'].count()
todos_jogos_casa=dados_inicio.groupby('AwayTeam')['AwayTeam'].count()
dados_inicio['Jogos Casa']=dados_inicio['Times'].map(todos_jogos_casa).sort_values().fillna(0)
dados_inicio['Jogos Fora']=dados_inicio['Times'].map(todos_jogos_fora).sort_values().fillna(0)
dados_inicio
# Out:
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# 1      English Premier League    14/08/93  Aston Villa             QPR
# 2      English Premier League    14/08/93      Chelsea       Blackburn
# 3      English Premier League    14/08/93    Liverpool  Sheffield Weds
# 4      English Premier League    14/08/93     Man City           Leeds
# ...                       ...         ...          ...             ...
# 11559  English Premier League  28/05/2023      Everton     Bournemouth
# 11560  English Premier League  28/05/2023        Leeds       Tottenham
# 11561  English Premier League  28/05/2023    Leicester        West Ham
# 11562  English Premier League  28/05/2023   Man United          Fulham
# 11563  English Premier League  28/05/2023  Southampton       Liverpool
#
#        HomeGoals  AwayGoals Result        Times  Gols time  Gols casa  \
# ...

# %% [markdown]
# Modificando os tipos das colunas

# %%
dados_inicio[['Gols time','Gols casa','Gols fora','Total jogos','Jogos Fora','Jogos Casa','HomeGoals','AwayGoals']]=dados_inicio[['Gols time','Gols casa','Gols fora','Total jogos','Jogos Fora','Jogos Casa','HomeGoals','AwayGoals']].astype(np.int64)
dados_inicio.info()
dados_inicio
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11564 entries, 0 to 11563
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       11564 non-null  object
#  1   Date         11564 non-null  object
#  2   HomeTeam     11564 non-null  object
#  3   AwayTeam     11564 non-null  object
#  4   HomeGoals    11564 non-null  int64
#  5   AwayGoals    11564 non-null  int64
#  6   Result       11564 non-null  object
#  7   Times        50 non-null     object
#  8   Gols time    11564 non-null  int64
#  9   Gols casa    11564 non-null  int64
#  10  Gols fora    11564 non-null  int64
#  11  Total jogos  11564 non-null  int64
#  12  Jogos Casa   11564 non-null  int64
#  13  Jogos Fora   11564 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 1.2+ MB
#                        League        Date     HomeTeam        AwayTeam  \
# 0      English Premier League    14/08/93      Arsenal        Coventry
# ...

# %% [markdown]
# removendo coluna

# %%
dados_inicio=dados_inicio.drop(columns=['League'])
dados_inicio
# Out:
#              Date     HomeTeam        AwayTeam  HomeGoals  AwayGoals Result  \
# 0        14/08/93      Arsenal        Coventry          0          3      A
# 1        14/08/93  Aston Villa             QPR          4          1      H
# 2        14/08/93      Chelsea       Blackburn          1          2      A
# 3        14/08/93    Liverpool  Sheffield Weds          2          0      H
# 4        14/08/93     Man City           Leeds          1          1      D
# ...           ...          ...             ...        ...        ...    ...
# 11559  28/05/2023      Everton     Bournemouth          1          0      H
# 11560  28/05/2023        Leeds       Tottenham          1          4      A
# 11561  28/05/2023    Leicester        West Ham          2          1      H
# 11562  28/05/2023   Man United          Fulham          2          1      H
# 11563  28/05/2023  Southampton       Liverpool          4          4      D
#
# ...

# %%
dados_inicio['Media gols']=(dados_inicio['Gols time']/dados_inicio['Total jogos']).fillna(0)
dados_inicio['Media gols casa']=(dados_inicio['Gols casa']/dados_inicio['Total jogos']).fillna(0)
dados_inicio['Media gols fora']=(dados_inicio['Gols fora']/dados_inicio['Total jogos']).fillna(0)

dados_inicio
# Out:
#              Date     HomeTeam        AwayTeam  HomeGoals  AwayGoals Result  \
# 0        14/08/93      Arsenal        Coventry          0          3      A
# 1        14/08/93  Aston Villa             QPR          4          1      H
# 2        14/08/93      Chelsea       Blackburn          1          2      A
# 3        14/08/93    Liverpool  Sheffield Weds          2          0      H
# 4        14/08/93     Man City           Leeds          1          1      D
# ...           ...          ...             ...        ...        ...    ...
# 11559  28/05/2023      Everton     Bournemouth          1          0      H
# 11560  28/05/2023        Leeds       Tottenham          1          4      A
# 11561  28/05/2023    Leicester        West Ham          2          1      H
# 11562  28/05/2023   Man United          Fulham          2          1      H
# 11563  28/05/2023  Southampton       Liverpool          4          4      D
#
# ...

# %% [markdown]
# Criando gráfico do número de gols de cada time

# %%
px.bar(data_frame=dados_inicio,x='Times',y='Gols time',title='Total de gols')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Ciando gráfico média de gols por time

# %%
px.scatter(data_frame=dados_inicio,x='Times',y='Media gols',title='Média de gols',size='Media gols')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(data_frame=dados_inicio,x='Times',y='Media gols casa',title='Média de gols casa',size='Media gols casa')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(data_frame=dados_inicio,x='Times',y='Media gols fora',title='Média de gols fora',size='Media gols fora')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Calculando o número de vitorias,derrotas e empates de cada time

# %%
resultados_casa=dados_inicio.groupby('HomeTeam')['Result'].value_counts()
resultados_fora=dados_inicio.groupby('AwayTeam')['Result'].value_counts()

# %%
vitorias_casa = {}
derrotas_casa = {}
empates_casa = {}
vitorias_fora = {}
derrotas_fora = {}
empates_fora = {}
for index, row in dados_inicio.iterrows():
    home_team = row['HomeTeam']
    away_team = row['AwayTeam']
    result = row['Result']

    if result == 'H':
        vitorias_casa[home_team] = vitorias_casa.get(home_team, 0) + 1
        derrotas_fora[away_team] = derrotas_fora.get(away_team, 0) + 1
    elif result == 'A':
        vitorias_fora[away_team] = vitorias_fora.get(away_team, 0) + 1
        derrotas_casa[home_team] = derrotas_casa.get(home_team, 0) + 1
    else:
        empates_casa[home_team] = empates_casa.get(home_team, 0) + 1
        empates_fora[away_team] = empates_fora.get(away_team, 0) + 1

# Adicionando as colunas ao DataFrame
dados_inicio['Vitorias Casa'] = dados_inicio['Times'].map(vitorias_casa).fillna(0).astype(int)
dados_inicio['Derrotas Casa'] = dados_inicio['Times'].map(derrotas_casa).fillna(0).astype(int)
dados_inicio['Empates Casa'] = dados_inicio['Times'].map(empates_casa).fillna(0).astype(int)
dados_inicio['Vitorias Fora'] = dados_inicio['Times'].map(vitorias_fora).fillna(0).astype(int)
dados_inicio['Derrotas Fora'] = dados_inicio['Times'].map(derrotas_fora).fillna(0).astype(int)
dados_inicio['Empates Fora'] = dados_inicio['Times'].map(empates_fora).fillna(0).astype(int)

# %%
dados_inicio
# Out:
#              Date     HomeTeam        AwayTeam  HomeGoals  AwayGoals Result  \
# 0        14/08/93      Arsenal        Coventry          0          3      A
# 1        14/08/93  Aston Villa             QPR          4          1      H
# 2        14/08/93      Chelsea       Blackburn          1          2      A
# 3        14/08/93    Liverpool  Sheffield Weds          2          0      H
# 4        14/08/93     Man City           Leeds          1          1      D
# ...           ...          ...             ...        ...        ...    ...
# 11559  28/05/2023      Everton     Bournemouth          1          0      H
# 11560  28/05/2023        Leeds       Tottenham          1          4      A
# 11561  28/05/2023    Leicester        West Ham          2          1      H
# 11562  28/05/2023   Man United          Fulham          2          1      H
# 11563  28/05/2023  Southampton       Liverpool          4          4      D
#
# ...

# %%
total_vitorias=dados_inicio['Vitorias Casa'] + dados_inicio['Vitorias Fora']
total_derrotas=dados_inicio['Derrotas Casa'] + dados_inicio['Derrotas Fora']
total_empates=dados_inicio['Empates Casa'] + dados_inicio['Empates Fora']

dados_inicio['Vitorias total']=total_vitorias
dados_inicio['Derrotas total']=total_derrotas
dados_inicio['Empates total']=total_empates
dados_inicio
# Out:
#              Date     HomeTeam        AwayTeam  HomeGoals  AwayGoals Result  \
# 0        14/08/93      Arsenal        Coventry          0          3      A
# 1        14/08/93  Aston Villa             QPR          4          1      H
# 2        14/08/93      Chelsea       Blackburn          1          2      A
# 3        14/08/93    Liverpool  Sheffield Weds          2          0      H
# 4        14/08/93     Man City           Leeds          1          1      D
# ...           ...          ...             ...        ...        ...    ...
# 11559  28/05/2023      Everton     Bournemouth          1          0      H
# 11560  28/05/2023        Leeds       Tottenham          1          4      A
# 11561  28/05/2023    Leicester        West Ham          2          1      H
# 11562  28/05/2023   Man United          Fulham          2          1      H
# 11563  28/05/2023  Southampton       Liverpool          4          4      D
#
# ...

# %% [markdown]
# **Criando um novo dataframe**

# %%
dados_resultados=pd.DataFrame(dados_inicio[['Times','Gols time','Gols casa','Gols fora','Media gols fora','Media gols casa','Vitorias Casa','Derrotas Casa','Empates Casa','Vitorias Fora','Derrotas Fora','Empates Fora','Vitorias total','Derrotas total','Empates total','Total jogos']])

# %%
dados_resultados
# Out:
#              Times  Gols time  Gols casa  Gols fora  Media gols fora  \
# 0          Arsenal       2065       1182        883         0.769164
# 1      Aston Villa       1259        681        578         0.558994
# 2         Barnsley         37         25         12         0.315789
# 3       Birmingham        273        162        111         0.417293
# 4        Blackburn        859        507        352         0.538226
# ...            ...        ...        ...        ...              ...
# 11559          NaN          0          0          0         0.000000
# 11560          NaN          0          0          0         0.000000
# 11561          NaN          0          0          0         0.000000
# 11562          NaN          0          0          0         0.000000
# 11563          NaN          0          0          0         0.000000
#
#        Media gols casa  Vitorias Casa  Derrotas Casa  Empates Casa  \
# 0             1.029617            374             72           128
# ...

# %% [markdown]
# Retirando valores dos jogos no dataframe inicio

# %%
dados_inicio
# Out:
#              Date     HomeTeam        AwayTeam  HomeGoals  AwayGoals Result  \
# 0        14/08/93      Arsenal        Coventry          0          3      A
# 1        14/08/93  Aston Villa             QPR          4          1      H
# 2        14/08/93      Chelsea       Blackburn          1          2      A
# 3        14/08/93    Liverpool  Sheffield Weds          2          0      H
# 4        14/08/93     Man City           Leeds          1          1      D
# ...           ...          ...             ...        ...        ...    ...
# 11559  28/05/2023      Everton     Bournemouth          1          0      H
# 11560  28/05/2023        Leeds       Tottenham          1          4      A
# 11561  28/05/2023    Leicester        West Ham          2          1      H
# 11562  28/05/2023   Man United          Fulham          2          1      H
# 11563  28/05/2023  Southampton       Liverpool          4          4      D
#
# ...

# %% [markdown]
# **Já analisamos a média de gols dentro e fora de casa, então não precisamos mais dessas colunas**

# %%
dados_resultados
# Out:
#              Times  Gols time  Gols casa  Gols fora  Media gols fora  \
# 0          Arsenal       2065       1182        883         0.769164
# 1      Aston Villa       1259        681        578         0.558994
# 2         Barnsley         37         25         12         0.315789
# 3       Birmingham        273        162        111         0.417293
# 4        Blackburn        859        507        352         0.538226
# ...            ...        ...        ...        ...              ...
# 11559          NaN          0          0          0         0.000000
# 11560          NaN          0          0          0         0.000000
# 11561          NaN          0          0          0         0.000000
# 11562          NaN          0          0          0         0.000000
# 11563          NaN          0          0          0         0.000000
#
#        Media gols casa  Vitorias Casa  Derrotas Casa  Empates Casa  \
# 0             1.029617            374             72           128
# ...

# %% [markdown]
# **Vitórias gerais no campeonato**

# %%
vitorias=(dados_resultados['Vitorias total']/dados_resultados['Total jogos']).fillna(0)
dados_resultados['Aproveitamento vitorias']=vitorias

# %%
px.scatter(data_frame=dados_resultados,x='Times',y='Vitorias total',title='Times',size='Vitorias total')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Derrotas gerais no campeonato

# %%
Aproveitamento_derrotas=(dados_resultados['Derrotas total']/dados_resultados['Total jogos']).fillna(0)
dados_resultados['Aproveitamento derrotas']=Aproveitamento_derrotas

# %%
dados_resultados.drop(columns=['Media gols fora','Media gols casa'])
# Out:
#              Times  Gols time  Gols casa  Gols fora  Vitorias Casa  \
# 0          Arsenal       2065       1182        883            374
# 1      Aston Villa       1259        681        578            207
# 2         Barnsley         37         25         12              7
# 3       Birmingham        273        162        111             50
# 4        Blackburn        859        507        352            156
# ...            ...        ...        ...        ...            ...
# 11559          NaN          0          0          0              0
# 11560          NaN          0          0          0              0
# 11561          NaN          0          0          0              0
# 11562          NaN          0          0          0              0
# 11563          NaN          0          0          0              0
#
#        Derrotas Casa  Empates Casa  Vitorias Fora  Derrotas Fora  \
# 0                 72           128            256            167
# ...

# %%
px.scatter(data_frame=dados_resultados,x='Times',y='Derrotas total',title='Número de derrotas',size='Derrotas total')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Empates gerais na liga

# %%
aproveitamento_empates=(dados_resultados['Empates total']/dados_resultados['Total jogos']).fillna(0)
dados_resultados['Aproveitamento empates']=aproveitamento_empates

# %%
px.scatter(data_frame=dados_resultados,x='Times',y='Empates total',title='Número de empates',size='Empates total')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Porcentagem de vitorias de cada time **

# %%
px.scatter(data_frame=dados_resultados,x='Times',y='Aproveitamento vitorias',title='Aproveitamento vitorias',size='Aproveitamento vitorias')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Porcentagem de derrotas de cada time **

# %%
px.scatter(data_frame=dados_resultados,x='Times',y='Aproveitamento derrotas',title='Aproveitamento derrotas',size='Aproveitamento derrotas')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Porcentagem de empates de cada time

# %%
px.scatter(data_frame=dados_resultados,x='Times',y='Aproveitamento empates',title='Aproveitamento empates',size='Aproveitamento empates')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dados_resultados
# Out:
#              Times  Gols time  Gols casa  Gols fora  Vitorias Casa  \
# 0          Arsenal       2065       1182        883            374
# 1      Aston Villa       1259        681        578            207
# 2         Barnsley         37         25         12              7
# 3       Birmingham        273        162        111             50
# 4        Blackburn        859        507        352            156
# ...            ...        ...        ...        ...            ...
# 11559          NaN          0          0          0              0
# 11560          NaN          0          0          0              0
# 11561          NaN          0          0          0              0
# 11562          NaN          0          0          0              0
# 11563          NaN          0          0          0              0
#
#        Derrotas Casa  Empates Casa  Vitorias Fora  Derrotas Fora  \
# 0                 72           128            256            167
# ...

# %% [markdown]
# **Número de pontos já feitos em toda a liga **

# %%
total_pontos=(dados_resultados['Vitorias total']*3) + dados_resultados['Empates total']
dados_resultados['Total pontos']=total_pontos
dados_resultados
# Out:
#              Times  Gols time  Gols casa  Gols fora  Vitorias Casa  \
# 0          Arsenal       2065       1182        883            374
# 1      Aston Villa       1259        681        578            207
# 2         Barnsley         37         25         12              7
# 3       Birmingham        273        162        111             50
# 4        Blackburn        859        507        352            156
# ...            ...        ...        ...        ...            ...
# 11559          NaN          0          0          0              0
# 11560          NaN          0          0          0              0
# 11561          NaN          0          0          0              0
# 11562          NaN          0          0          0              0
# 11563          NaN          0          0          0              0
#
#        Derrotas Casa  Empates Casa  Vitorias Fora  Derrotas Fora  \
# 0                 72           128            256            167
# ...

# %%
px.bar(data_frame=dados_resultados,x='Times',y='Total pontos',title='Total de pontos em toda Premier League')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
